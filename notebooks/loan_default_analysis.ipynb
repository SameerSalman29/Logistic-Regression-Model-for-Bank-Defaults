# %% [markdown]
# # Loan Default Analysis
#
# This notebook walks through generating a synthetic dataset, training a Logistic Regression model, and evaluating it.

# %%
# !python ../src/generate_data.py
# !python ../src/train.py
